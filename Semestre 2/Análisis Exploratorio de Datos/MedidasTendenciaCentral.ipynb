# %% [markdown]
# # Medidas de tendencia central
#
#
# Veremos la media la moda y la mediana $X_5$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats

data = (10*np.random.normal(0, 4, 1000)).astype(int) / 100
#data[0: 1000] = np.random.normal(10, 1, 1000)
#data = data**2
#print(data)
#data = np.random.rand(100)

mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0][0]

H = plt.hist(data, bins=50)
plt.axvline(x=mean, ls = "-", color='#ff0000', alpha=std)
plt.axvline(x=median, ls = "-", color='#00ff00', alpha=std)
plt.axvline(x=mode, ls = "-", color='#0000ff', alpha=std)

# %%
data = data ** 2
std = np.std(data)
mean = np.mean(data)
print('skew: ' + str(stats.skew(data)))
print(mean, std)
H = plt.hist(data, bins=50)
plt.axvline(x=mean-std, ls = "-", color='#ff0000', alpha=std)
plt.axvline(x=mean+std, ls = "-", color='#ff0000', alpha=std)
# Out:
# skew: 2.803887887598696
# 0.15719072999999997 0.22432417140171743

# %% [markdown]
# # 2 variables

# %%
data2 = (10*np.random.normal(0, 4, 1000)).astype(int) / 100
data2 = data**2 + data2
plt.scatter(data, data2)
plt.plot([-1,0,1],[1, 0, 1], color='red')

# %%
# Out:
# -2.687515899358526
